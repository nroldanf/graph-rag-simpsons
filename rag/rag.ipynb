# %%
import pandas as pd
import numpy as np
import faiss
from typing import List, Dict, Any
import json
import re
import zipfile
import os
from dotenv import load_dotenv
from faiss import write_index, read_index
from llama_index.llms.ollama import Ollama
from llama_index.core.llms import ChatMessage
from llama_index.embeddings.ollama import OllamaEmbedding
import yaml
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Document

# %%
# load cofig.yaml
with open("../config.yaml", "r") as f:
	config = yaml.safe_load(f)

# %%
embedding_model = OllamaEmbedding(
    model_name=config["OLLAMA_EMBEDDING_MODEL"],
    base_url="http://localhost:11434",
)

# %%
"""Load all Simpsons CSV files into dataframes from data/simpsons/"""
files_path = "../data/simpsons/"

characters_df = pd.read_csv(os.path.join(files_path, 'simpsons_characters.csv'))
episodes_df = pd.read_csv(os.path.join(files_path, 'simpsons_episodes.csv'))
locations_df = pd.read_csv(os.path.join(files_path, 'simpsons_locations.csv'))
script_lines_df = pd.read_csv(
    os.path.join(files_path, 'simpsons_script_lines.csv'),
    quotechar='"',
    dtype={
        "speaking_line": "string", 
        "character_id": "string", 
    },
    na_values=["", "NaN"],
    low_memory=False
)

# speaking_line to boolean
script_lines_df["speaking_line"] = script_lines_df["speaking_line"].map({"TRUE": True, "FALSE": False})

# character_id to int64 with support for NaN
script_lines_df["character_id"] = pd.to_numeric(script_lines_df["character_id"], errors="coerce").astype("Int64")


print(f"Loaded {len(characters_df)} characters")
print(f"Loaded {len(episodes_df)} episodes")
print(f"Loaded {len(locations_df)} locations")
print(f"Loaded {len(script_lines_df)} script lines")
# Out:
# Loaded 6722 characters
# Loaded 600 episodes
# Loaded 4459 locations
# Loaded 158271 script lines

# %%
episodes_df.sort_values(by=["season", "id"], inplace=True)
script_lines_df.sort_values(by=["episode_id", "number"], inplace=True)

# Use the episode_id from script_lines_df to get the episode title season and the number_in_season from episodes_df
merged_lines_df = script_lines_df.merge(
  episodes_df[["id", "title", "season", "number_in_season", "number_in_series"]],
  left_on="episode_id",
  right_on="id",
  how="left",
  suffixes=("", "_episode"),
)
# use the location_id from script_lines_df to get the location name from locations_df
merged_lines_df = merged_lines_df.merge(
  locations_df[["id", "normalized_name"]],
  left_on="location_id",
  right_on="id",
  how="left",
  suffixes=("", "_location"),
)
# rename the column to "location_name"
merged_lines_df.rename(columns={"normalized_name": "location_name"}, inplace=True)
# use the character_id from script_lines_df to get the character name from characters_df

# concatenate all the raw_text when speaking_line == True or true into a single string
# for a given episode_id
merged_lines_df["speaking_line"] = merged_lines_df["speaking_line"].astype(bool)

# %%
merged_lines_df.head(3)
# Out:
#    id  episode_id  number                                      raw_text  \
# 0   1           1       0  (Street: ext. street - establishing - night)
# 1   2           1       1                       (Car: int. car - night)
# 2   3           1       2           Marge Simpson: Ooo, careful, Homer.
#
#   timestamp_in_ms  speaking_line  character_id  location_id  \
# 0            8000           True          <NA>          1.0
# 1            8000           True          <NA>          2.0
# 2            8000           True             1          2.0
#
#   raw_character_text raw_location_text          spoken_words  \
# 0                NaN            Street                   NaN
# 1                NaN               Car                   NaN
# 2      Marge Simpson               Car  Ooo, careful, Homer.
#
#      normalized_text word_count  id_episode  \
# 0                NaN        NaN           1
# 1                NaN        NaN           1
# 2  ooo careful homer          3           1
#
#                                title  season  number_in_season  \
# 0  Simpsons Roasting on an Open Fire       1                 1
# 1  Simpsons Roasting on an Open Fire       1                 1
# 2  Simpsons Roasting on an Open Fire       1                 1
#
#    number_in_series  id_location location_name
# 0                 1          1.0        street
# 1                 1          2.0           car
# 2                 1          2.0           car

# %%
def get_episode_text(episode_id):
	episode_lines = merged_lines_df[merged_lines_df["episode_id"] == episode_id]
	episode_lines = episode_lines[~episode_lines["normalized_text"].isna()]
	# drop those where normalized_name is NaN
	episode_lines = episode_lines.dropna()
	speaking_lines = episode_lines[episode_lines["speaking_line"]]
	locations = speaking_lines["location_name"].tolist()
	characters = speaking_lines["raw_character_text"].str.lower().values
	text_lines = speaking_lines["normalized_text"].tolist()
	# Concatenate every location name from locations list with the corresponding speaking line from text_lines list and character from characters list
	# such as: "[location] character_name: speaking line"
	text_lines = [f"[{loc}] ({char}): {text}" for loc, char, text in zip(locations, characters, text_lines)]
	# Join all the text lines into a single string, separated by newlines
	return f"\n".join(text_lines)

# %%
output_dir = "../output"
os.makedirs(output_dir, exist_ok=True)
# Episodes ids to generate scripts for

written_episodes = []
skipped_episodes = []

episode_ids = episodes_df['id'].to_list()
#episode_ids = [128, 129]
for episode_id in episode_ids:
    if episode_id not in merged_lines_df["episode_id"].values:
        skipped_episodes.append({
            "episode_id": episode_id,
            "reason": "no script lines"
        })
        continue

    episode_text = get_episode_text(episode_id)

    title_row = merged_lines_df[merged_lines_df["episode_id"] == episode_id]

    # skip if no usable lines (e.g. only NaNs)
    if title_row.empty or not episode_text.strip():
        print(f"Skipping episode {episode_id} (no valid lines)")
        skipped_episodes.append({
            "episode_id": episode_id,
            "reason": "no valid lines"
        })
        continue

    title = title_row["title"].iloc[0]
    season = title_row["season"].iloc[0]
    number_in_season = title_row["number_in_season"].iloc[0]
    number_in_series = title_row["number_in_series"].iloc[0]

    episode_text = f"Season: {season}, Episode: {number_in_season}, Episode in series: {number_in_series}\n\n{episode_text}"
    episode_text = f"Title: {title}\n{episode_text}"
    written_episodes.append(episode_id)

# save into a file	
    with open(f"{output_dir}/scripts/season_{season}_episode_{episode_id}_text.txt", "w") as f:
            f.write(episode_text)

with open(f"{output_dir}/skipped_episodes.json", "w") as f:
    json.dump(skipped_episodes, f, indent=2)
    
print(len(skipped_episodes),"episodes not written, check 'skipped_episodes.json' file for more info")
# Out:
# 36 episodes not written, check 'skipped_episodes.json' file for more info

# %%
documents = []
all_docs_paths = os.listdir(f"../output/scripts")
# all_docs_paths = ["season_1_episode_1_text.txt"]
for doc_path in all_docs_paths:
	with open(f"../output/scripts/{doc_path}", "r") as f:
		text = f.read()
		documents.append(Document(text=text))
# Out:
# season_9_episode_179_text.txt
# season_18_episode_391_text.txt
# season_18_episode_390_text.txt
# season_8_episode_162_text.txt
# season_21_episode_462_text.txt
# season_21_episode_463_text.txt
# season_8_episode_163_text.txt
# season_26_episode_563_text.txt
# season_26_episode_562_text.txt
# season_11_episode_239_text.txt
# season_22_episode_481_text.txt
# season_11_episode_238_text.txt
# season_6_episode_111_text.txt
# season_22_episode_480_text.txt
# season_16_episode_338_text.txt
# season_16_episode_339_text.txt
# season_14_episode_294_text.txt
# season_7_episode_143_text.txt
# season_7_episode_142_text.txt
# season_14_episode_295_text.txt
# season_20_episode_425_text.txt
# season_8_episode_176_text.txt
# season_8_episode_177_text.txt
# season_18_episode_385_text.txt
# season_10_episode_223_text.txt
# season_15_episode_314_text.txt
# season_18_episode_384_text.txt
# season_10_episode_222_text.txt
# season_15_episode_315_text.txt
# season_23_episode_501_text.txt
# season_23_episode_500_text.txt
# season_9_episode_202_text.txt
# season_9_episode_203_text.txt
# season_1_episode_9_text.txt
# season_1_episode_8_text.txt
# season_24_episode_509_text.txt
# season_9_episode_189_text.txt
# season_9_episode_188_text.txt
# season_12_episode_262_text.txt
# season_12_episode_263_text.txt
# season_21_episode_448_text.txt
# season_21_episode_449_text.txt
# season_19_episode_401_text.txt
# season_5_episode_102_text.txt
# season_5_episode_103_text.txt
# season_13_episode_278_text.txt
# season_13_episode_279_text.txt
# season_7_episode_134_text.txt
# season_7_episode_135_text.txt
# season_4_episode_68_text.txt
# season_4_episode_69_text.txt
# season_22_episode_465_text.txt
# season_2_episode_20_text.txt
# season_2_episode_21_text.txt
# season_14_episode_313_text.txt
# season_14_episode_312_text.txt
# season_17_episode_376_text.txt
# season_17_episode_377_text.txt
# season_13_episode_280_text.txt
# season_20_episode_438_text.txt
# season_13_episode_281_text.txt
# season_20_episode_439_text.txt
# season_18_episode_398_text.txt
# season_18_episode_399_text.txt
# season_23_episode_487_text.txt
# season_25_episode_546_text.txt
# season_25_episode_547_text.txt
# season_24_episode_515_text.txt
# season_3_episode_56_text.txt
# season_3_episode_57_text.txt
# season_24_episode_514_text.txt
# season_9_episode_194_text.txt
# season_9_episode_195_text.txt
# season_25_episode_531_text.txt
# season_26_episode_554_text.txt
# season_26_episode_555_text.txt
# season_5_episode_91_text.txt
# season_8_episode_155_text.txt
# season_21_episode_455_text.txt
# season_5_episode_90_text.txt
# season_21_episode_454_text.txt
# season_8_episode_154_text.txt
# season_7_episode_129_text.txt
# season_16_episode_352_text.txt
# season_16_episode_353_text.txt
# season_22_episode_479_text.txt
# season_22_episode_478_text.txt
# season_4_episode_75_text.txt
# season_4_episode_74_text.txt
# season_18_episode_392_text.txt
# season_18_episode_393_text.txt
# season_26_episode_560_text.txt
# season_26_episode_561_text.txt
# season_20_episode_432_text.txt
# season_20_episode_433_text.txt
# season_8_episode_161_text.txt
# season_21_episode_461_text.txt
# season_21_episode_460_text.txt
# season_8_episode_160_text.txt
# season_6_episode_107_text.txt
# season_6_episode_106_text.txt
# season_22_episode_473_text.txt
# season_22_episode_472_text.txt
# season_24_episode_521_text.txt
# season_24_episode_520_text.txt
# season_19_episode_416_text.txt
# season_19_episode_417_text.txt
# season_2_episode_14_text.txt
# season_2_episode_15_text.txt
# season_1_episode_13_text.txt
# season_1_episode_12_text.txt
# season_13_episode_287_text.txt
# season_13_episode_286_text.txt
# season_2_episode_27_text.txt
# season_2_episode_26_text.txt
# season_17_episode_371_text.txt
# season_17_episode_370_text.txt
# season_25_episode_541_text.txt
# season_25_episode_540_text.txt
# season_3_episode_51_text.txt
# season_24_episode_512_text.txt
# season_24_episode_513_text.txt
# season_3_episode_50_text.txt
# season_25_episode_536_text.txt
# season_25_episode_537_text.txt
# season_26_episode_553_text.txt
# season_5_episode_96_text.txt
# season_21_episode_452_text.txt
# season_5_episode_97_text.txt
# season_21_episode_453_text.txt
# season_9_episode_193_text.txt
# season_9_episode_192_text.txt
# season_2_episode_19_text.txt
# season_2_episode_18_text.txt
# season_18_episode_400_text.txt
# season_4_episode_72_text.txt
# season_4_episode_73_text.txt
# season_15_episode_330_text.txt
# season_10_episode_207_text.txt
# season_15_episode_331_text.txt
# season_10_episode_206_text.txt
# season_16_episode_355_text.txt
# season_16_episode_354_text.txt
# season_18_episode_395_text.txt
# season_18_episode_394_text.txt
# season_24_episode_518_text.txt
# season_24_episode_519_text.txt
# season_11_episode_229_text.txt
# season_11_episode_228_text.txt
# season_7_episode_153_text.txt
# season_7_episode_152_text.txt
# season_26_episode_567_text.txt
# season_26_episode_566_text.txt
# season_20_episode_435_text.txt
# season_20_episode_434_text.txt
# season_8_episode_166_text.txt
# season_8_episode_167_text.txt
# season_4_episode_78_text.txt
# season_4_episode_79_text.txt
# season_22_episode_474_text.txt
# season_22_episode_475_text.txt
# season_24_episode_526_text.txt
# season_24_episode_527_text.txt
# season_9_episode_199_text.txt
# season_9_episode_198_text.txt
# season_21_episode_458_text.txt
# season_8_episode_158_text.txt
# season_8_episode_159_text.txt
# season_21_episode_459_text.txt
# season_19_episode_411_text.txt
# season_19_episode_410_text.txt
# season_26_episode_559_text.txt
# season_26_episode_558_text.txt
# season_18_episode_388_text.txt
# season_23_episode_496_text.txt
# season_15_episode_319_text.txt
# season_23_episode_497_text.txt
# season_18_episode_389_text.txt
# season_15_episode_318_text.txt
# season_1_episode_4_text.txt
# season_1_episode_5_text.txt
# season_3_episode_46_text.txt
# season_3_episode_47_text.txt
# season_2_episode_30_text.txt
# season_14_episode_299_text.txt
# season_4_episode_80_text.txt
# season_14_episode_298_text.txt
# season_2_episode_31_text.txt
# season_4_episode_81_text.txt
# season_17_episode_366_text.txt
# season_12_episode_251_text.txt
# season_17_episode_367_text.txt
# season_12_episode_250_text.txt
# season_14_episode_303_text.txt
# season_11_episode_234_text.txt
# season_14_episode_302_text.txt
# season_11_episode_235_text.txt
# season_13_episode_290_text.txt
# season_20_episode_428_text.txt
# season_13_episode_291_text.txt
# season_20_episode_429_text.txt
# season_16_episode_342_text.txt
# season_13_episode_275_text.txt
# season_16_episode_343_text.txt
# season_13_episode_274_text.txt
# season_15_episode_327_text.txt
# season_10_episode_210_text.txt
# season_7_episode_139_text.txt
# season_15_episode_326_text.txt
# season_7_episode_138_text.txt
# season_10_episode_211_text.txt
# season_11_episode_243_text.txt
# season_11_episode_242_text.txt
# season_22_episode_469_text.txt
# season_22_episode_468_text.txt
# season_4_episode_65_text.txt
# season_4_episode_64_text.txt
# season_6_episode_123_text.txt
# season_6_episode_122_text.txt
# season_17_episode_358_text.txt
# season_17_episode_359_text.txt
# season_9_episode_184_text.txt
# season_9_episode_185_text.txt
# season_21_episode_445_text.txt
# season_21_episode_444_text.txt
# season_20_episode_422_text.txt
# season_20_episode_423_text.txt
# season_8_episode_171_text.txt
# season_8_episode_170_text.txt
# season_6_episode_117_text.txt
# season_14_episode_309_text.txt
# season_22_episode_486_text.txt
# season_6_episode_116_text.txt
# season_14_episode_308_text.txt
# season_7_episode_144_text.txt
# season_14_episode_293_text.txt
# season_14_episode_292_text.txt
# season_7_episode_145_text.txt
# season_18_episode_382_text.txt
# season_10_episode_224_text.txt
# season_18_episode_383_text.txt
# season_10_episode_225_text.txt
# season_23_episode_506_text.txt
# season_23_episode_507_text.txt
# season_19_episode_406_text.txt
# season_19_episode_407_text.txt
# season_6_episode_128_text.txt
# season_12_episode_265_text.txt
# season_12_episode_264_text.txt
# season_24_episode_530_text.txt
# season_11_episode_248_text.txt
# season_16_episode_348_text.txt
# season_16_episode_349_text.txt
# season_7_episode_133_text.txt
# season_7_episode_132_text.txt

# %% [markdown]
# # Chunking

# %%
splitter = SentenceSplitter(
    chunk_size=1024,
    chunk_overlap=20,
)
# Nodes represent chunks of source documents in Llamaindex
nodes = splitter.get_nodes_from_documents(documents)

# %% [markdown]
# # Embeddings

# %%
texts = [node.text for node in nodes]

embeddings: List[List] = embedding_model.get_text_embedding_batch(texts, show_progress=True)
embeddings: np.ndarray = np.array(embeddings, dtype=np.float32)
# Out:
# Generating embeddings:   0%|          | 0/3399 [00:00<?, ?it/s]

# %%
np.savez_compressed(
    f"../output/embeddings/embeddings_bge_m3.npz",
    texts=np.array(texts),
    embeddings=embeddings
)

# %%
data = np.load(f"../output/embeddings/embeddings_bge_m3.npz", allow_pickle=True)
texts = data["texts"]
embeddings = data["embeddings"]

# %%
"""Build FAISS index for similarity search"""
dimension = embeddings.shape[1]
index = faiss.IndexFlatIP(dimension)  # Inner product for cosine similarity

# Normalize embeddings for cosine similarity
faiss.normalize_L2(embeddings)
index.add(embeddings.astype('float32'))

output_faiss_path = f"../output/faiss_index_bge_m3.index"
faiss.write_index(index, output_faiss_path)

# %%
# Initialize Ollama LLM
# https://docs.llamaindex.ai/en/stable/api_reference/llms/ollama/
llm = Ollama(
    model=config["OLLAMA_LLM_MODEL"],
    temperature=0.7,
    request_timeout = 7200,
)

# %%
query = "Who are all the relatives of Bart Simpson, including their relationships to each other?"

# %%
query_embedding = embedding_model.get_text_embedding_batch([query])
query_embedding: np.ndarray = np.array(query_embedding, dtype=np.float32)
faiss.normalize_L2(query_embedding)

scores, indices = index.search(query_embedding.astype('float32'), k=10)

results = []

for i, idx in enumerate(indices[0]):
    results.append({
        'content': texts[idx],
        'score': float(scores[0][i])
    })

# %%
query_1 = "Who are all the relatives of Bart Simpson, including their relationships to each other?"

# %%
query_2 = "Which characters interacted directly with Mr. Burns on the day of the shooting?"

# %%
query_3 = "What are the top 5 themes discussed in the episodes?"

# %%
query = query_2
"""Generate response using OpenAI with retrieved context"""
# Prepare context from retrieved documents

context = ""
for doc in results:
    context += f"{doc['content']}\n\n"

# Create prompt
prompt = f"""
You are a knowledgeable assistant about The Simpsons TV show. Use the following context to answer the user's question.

Context:
{context}

Question: {query}

Please provide a comprehensive answer based ONLY on the context provided. If the context doesn't contain enough information to fully answer the question, mention what information is available and what might be missing.

Answer:
"""

messages = [
    ChatMessage(
        role="system", 
        content="You are a helpful assistant specializing in The Simpsons TV show.",
    ),
    ChatMessage(
        role="user",
        content=prompt
    )
]
response = llm.chat(messages)

# %%
response
# Out:
# ChatResponse(message=ChatMessage(role=<MessageRole.ASSISTANT: 'assistant'>, additional_kwargs={'tool_calls': None, 'thinking': None}, blocks=[TextBlock(block_type='text', text='Based on the provided context, the following characters interacted directly with Mr. Burns on the day of the shooting:\n\n*   **Montgomery Burns:** He initiated the meeting at the Simpson home.\n*   **Homer Simpson:** He was present at the Simpson home during Mr. Burns\' visit.\n*   **Marge Simpson:** She offered Mr. Burns tea and marshmallow squares.\n*   **Waylon Smithers:** He provided information about the jade monkey and maps.\n*   **Bart Simpson:** He made comments to Mr. Burns.\n*   **Lisa Simpson:** She was present during the interaction.\n*   **Edna Krabappel:** She was present during the interaction.\n*   **Seymour Skinner:** He was present during the interaction.\n\nThe context doesn\'t provide details about the shooting itself, only Mr. Burns\' visit to the Simpson home. Therefore, we cannot determine if any of these characters were involved in or directly affected by a shooting. The context only mentions a "jade monkey" and a need to find it before the next full moon, but no shooting is mentioned.\n\n\n\n')]), raw={'model': 'gemma3n:e4b', 'created_at': '2025-07-06T10:04:34.175187Z', 'done': True, 'done_reason': 'stop', 'total_duration': 79561011458, 'load_duration': 12975974291, 'prompt_eval_count': 5653, 'prompt_eval_duration': 53230832000, 'eval_count': 231, 'eval_duration': 10530151166, 'message': Message(role='assistant', content='Based on the provided context, the following characters interacted directly with Mr. Burns on the day of the shooting:\n\n*   **Montgomery Burns:** He initiated the meeting at the Simpson home.\n*   **Homer Simpson:** He was present at the Simpson home during Mr. Burns\' visit.\n*   **Marge Simpson:** She offered Mr. Burns tea and marshmallow squares.\n*   **Waylon Smithers:** He provided information about the jade monkey and maps.\n*   **Bart Simpson:** He made comments to Mr. Burns.\n*   **Lisa Simpson:** She was present during the interaction.\n*   **Edna Krabappel:** She was present during the interaction.\n*   **Seymour Skinner:** He was present during the interaction.\n\nThe context doesn\'t provide details about the shooting itself, only Mr. Burns\' visit to the Simpson home. Therefore, we cannot determine if any of these characters were involved in or directly affected by a shooting. The context only mentions a "jade monkey" and a need to find it before the next full moon, but no shooting is mentioned.\n\n\n\n', thinking=None, images=None, tool_calls=None), 'usage': {'prompt_tokens': 5653, 'completion_tokens': 231, 'total_tokens': 5884}}, delta=None, logprobs=None, additional_kwargs={})

# %%
response.message.blocks[0].text
# Out:
# "Based on the provided context, the following characters interacted directly with Mr. Burns on the day of the shooting:\n\n*   **Waylon Smithers:** He informed Mr. Burns that the jade monkey and maps were found in Mr. Burns' glove compartment.\n*   **Charles Montgomery Burns:** He directly addressed Waylon Smithers and gave instructions regarding the jade monkey and the next full moon.\n\n\n\nThe context does not provide information about any other characters interacting with Mr. Burns on that day."
